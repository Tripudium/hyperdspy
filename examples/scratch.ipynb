# %%
# %load_ext autoreload
# %autoreload 2

# %%
from hyperliquid.info import Info
from hyperliquid.utils import constants

# %% [markdown]
# # <font color="grey">Data loading and handling</font>

# %% [markdown]
# Data is available in two forms: limit order book (LOB) and data sampled at fixed intervals (for example, seconds). The timestamps are given in nanosecond resolution as Unix timestamps, but the granularity of the data is not that fine. A simple dataloader and some helper function to convert Python datetime objects or strings of the form '240802.1450' into timestamps are provided. The 'book' data contains the bid and ask prices and volumes up to a specified depth (the maximum depth is currently 25).

# %%
info = Info(constants.MAINNET_API_URL, skip_ws=True)
info

# %%
user_state = info.user_state("0x6Cf933B34B0bFe4b6Ced3670aDea27d161938956")
print(user_state)
# Out:
# {'marginSummary': {'accountValue': '34.3875', 'totalNtlPos': '346.935', 'totalRawUsd': '-312.5475', 'totalMarginUsed': '17.34675'}, 'crossMarginSummary': {'accountValue': '34.3875', 'totalNtlPos': '346.935', 'totalRawUsd': '-312.5475', 'totalMarginUsed': '17.34675'}, 'crossMaintenanceMarginUsed': '4.336687', 'withdrawable': '0.0', 'assetPositions': [{'type': 'oneWay', 'position': {'coin': 'BTC', 'szi': '0.005', 'leverage': {'type': 'cross', 'value': 20}, 'entryPx': '71590.0', 'positionValue': '346.935', 'unrealizedPnl': '-11.015', 'returnOnEquity': '-0.6154490851', 'liquidationPx': '52266.1616202532', 'marginUsed': '17.34675', 'maxLeverage': 40, 'cumFunding': {'allTime': '0.038253', 'sinceOpen': '0.038253', 'sinceChange': '0.0'}}}], 'time': 1770295236641}

# %%
constants.MAINNET_API_URL
# Out:
# 'https://api.hyperliquid.xyz'
